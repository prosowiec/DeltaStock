# %%
#https://query2.finance.yahoo.com/ws/fundamentals-timeseries/v1/finance/timeseries/AAPL?symbol=AAPL"
#https://query2.finance.yahoo.com/v8/finance/chart/AAPL?period1=1704145844&period2=1723236317&interval=1mo

# %%
from scraper import get_spy500_formWiki


get_spy500_formWiki()
# Out:
#     Symbol            Security             GICS Sector  \
# 0      MMM                  3M             Industrials
# 1      AOS         A. O. Smith             Industrials
# 2      ABT              Abbott             Health Care
# 3     ABBV              AbbVie             Health Care
# 4      ACN           Accenture  Information Technology
# ..     ...                 ...                     ...
# 498    XYL          Xylem Inc.             Industrials
# 499    YUM         Yum! Brands  Consumer Discretionary
# 500   ZBRA  Zebra Technologies  Information Technology
# 501    ZBH       Zimmer Biomet             Health Care
# 502    ZTS              Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# ...

# %%
from scraper import get_StockPrices
import pandas as pd

df = get_StockPrices('NVDA', startSelect='2020-01-02')
df
# Out:
#         adjClose        date ticker  Quarter  meanADJclose
# 0       5.973633  2020-01-02   NVDA  Q1-2020      6.285297
# 1       5.878018  2020-01-03   NVDA  Q1-2020      6.285297
# 2       5.902669  2020-01-06   NVDA  Q1-2020      6.285297
# 3       5.974131  2020-01-07   NVDA  Q1-2020      6.285297
# 4       5.985336  2020-01-08   NVDA  Q1-2020      6.285297
# ...          ...         ...    ...      ...           ...
# 1159  109.019997  2024-08-12   NVDA  Q3-2024    117.687650
# 1160  116.139999  2024-08-13   NVDA  Q3-2024    117.687650
# 1161  118.080002  2024-08-14   NVDA  Q3-2024    117.687650
# 1162  122.860001  2024-08-15   NVDA  Q3-2024    117.687650
# 1163  123.390099  2024-08-16   NVDA  Q3-2024    117.687650
#
# [1164 rows x 5 columns]

# %%
from scraper import get_companyfacts
#https://data.sec.gov/api/xbrl/companyfacts/CIK0000320193.json
mergedDF = get_companyfacts('0000320193')
mergedDF
# Out:
#                                                  finType  \
# 0                                        AccountsPayable
# 1                                        AccountsPayable
# 2                                 AccountsPayableCurrent
# 3                                 AccountsPayableCurrent
# 4                                 AccountsPayableCurrent
# ...                                                  ...
# 22738  IncrementalCommonSharesAttributableToShareBase...
# 22739  IncrementalCommonSharesAttributableToShareBase...
# 22740  IncrementalCommonSharesAttributableToShareBase...
# 22741                 OtherAssetsMiscellaneousNoncurrent
# 22742                 OtherAssetsMiscellaneousNoncurrent
#
#                                                    label  \
# 0               Accounts Payable (Deprecated 2009-01-31)
# 1               Accounts Payable (Deprecated 2009-01-31)
# 2                              Accounts Payable, Current
# ...

# %%
"""
https://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000114036124024352/ef20028273_8k.htm


https://data.sec.gov/api/xbrl/companyconcept/CIK0000320193/us-gaap/AccountsPayableCurrent.json - info about reports

https://data.sec.gov/api/xbrl/companyfacts/CIK0000320193.json

/0001140361|24|024352/
accessionNumber - 0001140361-24-024352

"""
# Out:
# '\nhttps://www.sec.gov/ix?doc=/Archives/edgar/data/0000320193/000114036124024352/ef20028273_8k.htm\n\n\nhttps://data.sec.gov/api/xbrl/companyconcept/CIK0000320193/us-gaap/AccountsPayableCurrent.json - info about reports\n\nhttps://data.sec.gov/api/xbrl/companyfacts/CIK0000320193.json\n\n/0001140361|24|024352/\naccessionNumber - 0001140361-24-024352\n\n'

# %%
from scraper import generate_CIK_TICKER
import spark_operations

sec_ticker = generate_CIK_TICKER()
sparkclass = spark_operations.sparkDelta()
sparkclass.saveDeltaTable(sec_ticker, 'ticker-sec')
#sparkclass.sparkStop()
sparkclass.readDeltaTable('ticker-sec')
sec_ticker
# Out:
# hadoop-azure is available
# azure-storage is available
#        cik_str ticker                               title      cik10D
# 0       320193   AAPL                          Apple Inc.  0000320193
# 1       789019   MSFT                      MICROSOFT CORP  0000789019
# 2      1045810   NVDA                         NVIDIA CORP  0001045810
# 3      1652044  GOOGL                       Alphabet Inc.  0001652044
# 4      1018724   AMZN                      AMAZON COM INC  0001018724
# ...        ...    ...                                 ...         ...
# 10206  2001699  HPAIW                      Helport AI Ltd  0002001699
# 10207  1991946  CGBSW              Crown LNG Holdings Ltd  0001991946
# 10208  1904616   BAKR  Baker Global Asset Management Inc.  0001904616
# 10209   808219  MHGUP      MERITAGE HOSPITALITY GROUP INC  0000808219
# 10210  1446250  BYMOF     Bayerische Motoren Werke AG/ADR  0001446250
#
# [10211 rows x 4 columns]

# %%
sparkclass.readDeltaTable('ticker-sec').show()
# Out:
# +-------+------+--------------------+----------+
# |cik_str|ticker|               title|    cik10D|
# +-------+------+--------------------+----------+
# |1519457| NMREF|Namibia Critical ...|0001519457|
# |1123596|  BABB|           BAB, INC.|0001123596|
# |1817004|  EZFL| EzFill Holdings Inc|0001817004|
# |1346346|  CMOT|Curtiss Motorcycl...|0001346346|
# |1014763|  AIMD|         Ainos, Inc.|0001014763|
# | 758743|  VIDE|  VIDEO DISPLAY CORP|0000758743|
# |1487718|  BLTH|AMERICAN BATTERY ...|0001487718|
# |1543637|  NUMD|   Nu-Med Plus, Inc.|0001543637|
# |1770141|  UPHL|      UpHealth, Inc.|0001770141|
# |1375195|  CRTG|  CORETEC GROUP INC.|0001375195|
# |1421981|  PTOP|Peer To Peer Network|0001421981|
# |1011509|  AUMN|  Golden Minerals Co|0001011509|
# |1906133|  ICCT|   iCoreConnect Inc.|0001906133|
# |1643988|  LPTV|    Loop Media, Inc.|0001643988|
# |  96793|   SSY|SUNLINK HEALTH SY...|0000096793|
# |1898604|  YOSH|Yoshiharu Global Co.|0001898604|
# ...

# %%
sparkclass = spark_operations.sparkDelta()
sparkclass.saveDeltaTable(sec_ticker, 'ticker-sec')

# %%
from scraper import get_SEC_filings


ticker = 'AAPL'

filings = get_SEC_filings(ticker)

filings
# Out:
#           accessionNumber  filingDate  reportDate        acceptanceDateTime  \
# 0    0000320193-24-000086  2024-08-13  2024-08-09  2024-08-13T19:02:12.000Z
# 1    0000320193-24-000084  2024-08-07  2024-08-05  2024-08-07T18:30:15.000Z
# 2    0001950047-24-005824  2024-08-05              2024-08-05T16:32:46.000Z
# 3    0000320193-24-000081  2024-08-02  2024-06-29  2024-08-01T18:03:34.000Z
# 4    0000320193-24-000080  2024-08-01  2024-08-01  2024-08-01T16:30:26.000Z
# ..                    ...         ...         ...                       ...
# 995  0001181431-14-005066  2014-02-04  2014-02-01  2014-02-04T18:33:20.000Z
# 996  0001181431-14-005065  2014-02-04  2014-02-01  2014-02-04T18:33:00.000Z
# 997  0001181431-14-005064  2014-02-04  2014-02-01  2014-02-04T18:32:22.000Z
# 998  0001181431-14-005063  2014-02-04  2014-02-01  2014-02-04T18:32:03.000Z
# 999  0001181431-14-005062  2014-02-04  2014-02-01  2014-02-04T18:31:30.000Z
#
# ...

# %%
from scraper import unpackSECjson

unpackSECjson('CIK0000320193')
# Out:
#                                                  finType           val  \
# 0                                        AccountsPayable  5.520000e+09
# 1                                        AccountsPayable  4.854000e+09
# 2                                 AccountsPayableCurrent  5.520000e+09
# 3                                 AccountsPayableCurrent  5.520000e+09
# 4                                 AccountsPayableCurrent  5.601000e+09
# ...                                                  ...           ...
# 22738  IncrementalCommonSharesAttributableToShareBase...  5.885300e+07
# 22739  IncrementalCommonSharesAttributableToShareBase...  6.212800e+07
# 22740  IncrementalCommonSharesAttributableToShareBase...  6.065400e+07
# 22741                 OtherAssetsMiscellaneousNoncurrent  3.905300e+10
# 22742                 OtherAssetsMiscellaneousNoncurrent  4.690600e+10
#
#                        accn    fy  fp    form       filed      frame  \
# ...
